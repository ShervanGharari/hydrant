# %%
import xarray as xr
import hydrant.ObjectiveFunctions.ObjectiveFunctions as Obj

# %%
# objective function calculation
observation  = xr.open_dataset('./data/ObjectiveFunctions/Obs/Obs1.nc')
simulation   = xr.open_dataset('./data/ObjectiveFunctions/Sim/sim.nc')
Objective = Obj.ObjectiveFunction(observation,
                                  simulation,
                                  info_obs={'var': 'Flow',
                                            'var_id': 'COMID',
                                            'dim_id': 'n',
                                            'var_time': 'time',
                                            'dim_time': 'time',
                                            'var_extra': ['LATITUDE',\
                                                          'LONGITUDE',\
                                                          'DRAINAGE_AREA_GROSS',\
                                                          'DRAINAGE_AREA_EFFECT',\
                                                          'STATION_NAME']},
                                  info_sim={'var': 'IRFroutedRunoff',
                                            'var_id': 'reachID',
                                            'dim_id': 'x',
                                            'var_time': 'time',
                                            'dim_time': 'time'},
                                  TimeStep = 'daily')
Objective
# Out:
# <xarray.Dataset>
# Dimensions:                   (time: 725, ID: 1)
# Coordinates:
#   * time                      (time) datetime64[ns] 1980-01-06 ... 1981-12-30
#   * ID                        (ID) int64 71028585
# Data variables:
#     obs                       (ID, time) float64 ...
#     sim                       (time, ID) float32 ...
#     obs_LATITUDE              (ID) float64 ...
#     obs_LONGITUDE             (ID) float64 ...
#     obs_DRAINAGE_AREA_GROSS   (ID) float64 ...
#     obs_DRAINAGE_AREA_EFFECT  (ID) float64 ...
#     obs_STATION_NAME          (ID) object ...
#     KGE                       (ID) float64 0.36
#     NSE                       (ID) float64 -0.2903
#     RMSE                      (ID) float64 51.76
