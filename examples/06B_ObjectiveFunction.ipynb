# %%
import numpy as np
import pandas as pd
import xarray as xr
import hydrant.ObjectiveFunctions.ObjectiveFunctions as Obj

# %%
# objective function calculation
observation  = xr.open_dataset('./data/ObjectiveFunctions/Obs/Obs1.nc')
simulation   = xr.open_dataset('./data/ObjectiveFunctions/Sim/sim.nc')
Objective = Obj.ObjectiveFunction(observation,
                                  simulation,
                                  info_obs={'var': 'Flow',
                                            'var_id': 'COMID',
                                            'dim_id': 'n',
                                            'var_time': 'time',
                                            'dim_time': 'time'},
                                  info_sim={'var': 'IRFroutedRunoff',
                                            'var_id': 'reachID',
                                            'dim_id': 'x',
                                            'var_time': 'time',
                                            'dim_time': 'time'},
                                  TimeStep='daily')
Objective
# Out:
# <xarray.Dataset>
# Dimensions:  (ID: 1, time: 27395)
# Coordinates:
#   * time     (time) datetime64[ns] 1950-01-01 1950-01-02 ... 2025-01-01
# Dimensions without coordinates: ID
# Data variables:
#     obs      (ID, time) float64 ...
#     ID       (ID) int64 ...
# <xarray.Dataset>
# Dimensions:  (time: 725, ID: 1185)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-06 1980-01-07 ... 1981-12-30
# Dimensions without coordinates: ID
# Data variables:
#     ID       (ID) int32 ...
#     sim      (time, ID) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 2.2.3 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     history:      Mon Jul 22 13:22:03 2024: cdo mergetime *.nc outfile.nc
#     CDO:          Climate Data Operators version 2.2.1 (https://mpimet.mpg.de...
# /home/shg096/PyGMOAon/env/pygmo-env/lib/python3.8/site-packages/hydrant/ObjectiveFunctions/ObjectiveFunctions.py:28: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   obs = obs.rename({info_obs['var']: 'obs', info_obs['var_id']: 'ID', info_obs['var_time']: 'time'})
# /home/shg096/PyGMOAon/env/pygmo-env/lib/python3.8/site-packages/hydrant/ObjectiveFunctions/ObjectiveFunctions.py:32: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   obs = obs.rename({info_obs['dim_time']: 'time'})
# /home/shg096/PyGMOAon/env/pygmo-env/lib/python3.8/site-packages/hydrant/ObjectiveFunctions/ObjectiveFunctions.py:35: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   sim = sim.rename({info_sim['var']: 'sim', info_sim['var_id']: 'ID', info_sim['var_time']: 'time'})
# /home/shg096/PyGMOAon/env/pygmo-env/lib/python3.8/site-packages/hydrant/ObjectiveFunctions/ObjectiveFunctions.py:39: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   sim = sim.rename({info_sim['dim_time']: 'time'})

# %%
Objective
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 725, ID: 1)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-06 1980-01-07 ... 1981-12-30
#   * ID       (ID) int64 71028585
# Data variables:
#     obs      (ID, time) float64 ...
#     sim      (time, ID) float32 ...
#     KGE      (ID) float64 0.36
#     NSE      (ID) float64 -0.2903
#     RMSE     (ID) float64 51.76
